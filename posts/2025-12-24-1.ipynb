# %% [markdown]
# ---
# title: "Question Answering"
# date: 2025-12-24
# ---

# %% [markdown]
# Я прошел раздел Fine-tuning a pretrained model в рамках [Hugging Face Course](huggingface.co/course). В конце раздела предлагается углубить знания с помощью:
# - 🤗 Transformers task guides for specific NLP tasks
# - [🤗 Transformers examples](https://huggingface.co/docs/transformers/main/en/notebooks) for comprehensive notebooks
#
# Меня интересует [Question Answering (QA)](https://huggingface.co/docs/transformers/main/en/tasks/question_answering)

# %% [markdown]
# #### Question Answering

# %% [markdown]
# QA tasts return an answer given a question. There are two common types of question answering tasks. The difference between them в том как *именно* формируется ответ.

# %% [markdown]
# #### Extractive QA (извлекающие)

# %% [markdown]
# Модели **не придумывают формулировку**, а **находят и "вырезают"** фрагмент текста **прямо из представленного контекста**

# %% [markdown]
# #### Abstractive QA (абстрактивное)

# %% [markdown]
# Модель **генерирует ответ своими словами**, опираясь на контекст.
